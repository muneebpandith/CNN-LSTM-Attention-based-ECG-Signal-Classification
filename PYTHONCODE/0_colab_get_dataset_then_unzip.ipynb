# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls -a
# Out:
# .  ..  .config	drive  sample_data

# %%
# !pip install wget
import wget
import os
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=8551434cec80abda184009e569be2b3433ba4b544db93f94e8d76b9ae0f6c814
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %%
url='https://cloudypipeline.com:9555/api/download/physionet2020training/PhysioNetChallenge2020_Training_CPSC.tar.gz/'
filename = wget.download(url)

# %%
url='https://cloudypipeline.com:9555/api/download/physionet2020training/PhysioNetChallenge2020_Training_2.tar.gz/'
filename = wget.download(url)

# %%
# !ls -a
# Out:
# .   .config  PhysioNetChallenge2020_Training_2.tar.gz	  sample_data
# ..  drive    PhysioNetChallenge2020_Training_CPSC.tar.gz

# %%
# !mkdir "drive//My Drive//DATA_TAR"
# Out:
# 'Colab Notebooks'   DDD_DS
#  DATA		    DDD_EEYESCHK
#  DATA2		   'Getting started.pdf'
#  datasets	   'Interested Student_Database_Bravura Solutions.gsheet'
#  DATA_TAR	    MTECHMINOT
# mkdir: cannot create directory ‘drive//My Drive//DATA’: File exists
# mkdir: cannot create directory ‘drive//My Drive//DATA_TAR’: File exists
# 'Colab Notebooks'   DDD_DS
#  DATA		    DDD_EEYESCHK
#  DATA2		   'Getting started.pdf'
#  datasets	   'Interested Student_Database_Bravura Solutions.gsheet'
#  DATA_TAR	    MTECHMINOT

# %%
# !ls "drive//My Drive"
# Out:
# 'Colab Notebooks'   DDD_DS
#  DATA		    DDD_EEYESCHK
#  DATA2		   'Getting started.pdf'
#  datasets	   'Interested Student_Database_Bravura Solutions.gsheet'
#  DATA_TAR	    MTECHMINOT

# %%
# !ls -a
# !mv "PhysioNetChallenge2020_Training_CPSC.tar.gz" "drive//My Drive//DATA_TAR"
# Out:
# .   .config  PhysioNetChallenge2020_Training_2.tar.gz	  sample_data
# ..  drive    PhysioNetChallenge2020_Training_CPSC.tar.gz

# %%
# !ls -a
# !mv "PhysioNetChallenge2020_Training_2.tar.gz" "drive//My Drive//DATA_TAR"
# Out:
# .  ..  .config	drive  PhysioNetChallenge2020_Training_2.tar.gz  sample_data

# %%
# !ls -a
# Out:
# .  ..  .config	drive  sample_data

# %%
# !rmdir "drive//My Drive//DATA" 
# !mkdir "drive//My Drive//DATA"
# Out:
# rmdir: failed to remove 'drive//My Drive//DATA': No such file or directory

# %%
# !ls "drive//My Drive//DATA_TAR"
# Out:
# PhysioNetChallenge2020_Training_2.tar.gz
# PhysioNetChallenge2020_Training_CPSC.tar.gz

# %%
# Out:
# PhysioNetChallenge2020_Training_2.tar.gz
# PhysioNetChallenge2020_Training_CPSC.tar.gz

# %%
# !ls "drive//My Drive//DATA"

# %%
# !tar -xzvf "drive//My Drive//DATA_TAR/PhysioNetChallenge2020_Training_CPSC.tar.gz" -C "drive//My Drive/DATA/"
# Out:
# Streaming output truncated to the last 5000 lines.
# Training_WFDB/A4378.hea
# Training_WFDB/A4379.mat
# Training_WFDB/A4379.hea
# Training_WFDB/A4380.mat
# Training_WFDB/A4380.hea
# Training_WFDB/A4381.mat
# Training_WFDB/A4381.hea
# Training_WFDB/A4382.mat
# Training_WFDB/A4382.hea
# Training_WFDB/A4383.mat
# Training_WFDB/A4383.hea
# Training_WFDB/A4384.mat
# Training_WFDB/A4384.hea
# Training_WFDB/A4385.mat
# Training_WFDB/A4385.hea
# Training_WFDB/A4386.mat
# Training_WFDB/A4386.hea
# Training_WFDB/A4387.mat
# Training_WFDB/A4387.hea
# Training_WFDB/A4388.mat
# Training_WFDB/A4388.hea
# Training_WFDB/A4389.mat
# Training_WFDB/A4389.hea
# Training_WFDB/A4390.mat
# Training_WFDB/A4390.hea
# Training_WFDB/A4391.mat
# Training_WFDB/A4391.hea
# Training_WFDB/A4392.mat
# Training_WFDB/A4392.hea
# Training_WFDB/A4393.mat
# Training_WFDB/A4393.hea
# Training_WFDB/A4394.mat
# Training_WFDB/A4394.hea
# Training_WFDB/A4395.mat
# Training_WFDB/A4395.hea
# Training_WFDB/A4396.mat
# ...

# %%
# !tar -xzvf "drive//My Drive//DATA_TAR/PhysioNetChallenge2020_Training_2.tar.gz" -C "drive//My Drive/DATA/"
# Out:
# Streaming output truncated to the last 5000 lines.
# Training_2/Q0983.mat
# Training_2/Q0984.hea
# Training_2/Q0984.mat
# Training_2/Q0985.hea
# Training_2/Q0985.mat
# Training_2/Q0986.hea
# Training_2/Q0986.mat
# Training_2/Q0987.hea
# Training_2/Q0987.mat
# Training_2/Q0988.hea
# Training_2/Q0988.mat
# Training_2/Q0989.hea
# Training_2/Q0989.mat
# Training_2/Q0990.hea
# Training_2/Q0990.mat
# Training_2/Q0991.hea
# Training_2/Q0991.mat
# Training_2/Q0992.hea
# Training_2/Q0992.mat
# Training_2/Q0993.hea
# Training_2/Q0993.mat
# Training_2/Q0994.hea
# Training_2/Q0994.mat
# Training_2/Q0995.hea
# Training_2/Q0995.mat
# Training_2/Q0996.hea
# Training_2/Q0996.mat
# Training_2/Q0997.hea
# Training_2/Q0997.mat
# Training_2/Q0998.hea
# Training_2/Q0998.mat
# Training_2/Q0999.hea
# Training_2/Q0999.mat
# Training_2/Q1000.hea
# Training_2/Q1000.mat
# Training_2/Q1001.hea
# Training_2/Q1001.mat
# Training_2/Q1003.hea
# Training_2/Q1003.mat
# Training_2/Q1004.hea
# Training_2/Q1004.mat
# ...

# %%
# Out:
# .  ..  .config	drive  sample_data  Training_2	Training_WFDB

# %%
# !ls "drive//My Drive//DATA_TAR"
# Out:
# PhysioNetChallenge2020_Training_2.tar.gz
# PhysioNetChallenge2020_Training_CPSC.tar.gz

# %%
# !ls "drive//My Drive//DATA/"
# Out:
# Training_2  Training_WFDB
